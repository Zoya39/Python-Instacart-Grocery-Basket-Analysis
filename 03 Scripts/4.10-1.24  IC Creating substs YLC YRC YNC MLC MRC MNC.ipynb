# %% [markdown]
# # 4.10 Part4
# #### 1-creating subst for Yang Loyal Consumer
# #### 2- creating subset for Mature Loyal Consumer
# #### 3-creating subst for Yang Regular Consumer
# #### 4- creating subset for Mature Regular Consumer
# #### 5-creating subset for Young NewCustomer
# #### 6-creating subset for Mature New customer

# %% [markdown]
# ###  Importing libraries and df w/o PII

# %%
import pandas as pd
import numpy as np
import os

# %%
path=r'C:\Users\user\07-2023 Instacart Basket Analysis\02 Data'

# %%
df=pd.read_pickle(os.path.join(path,'Prepared Data', 'sample_revenue.pkl'))

# %%
df.columns
# Out:
# Index(['user_id', 'Gender', 'STATE', 'Age', 'date_joined', 'n_dependants',
#        'fam_status', 'income', 'product_id', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'order_id', 'eval_set', 'order_number',
#        'day_of_week', 'order_hour_of_day', 'days_since_prior_order',
#        'add_to_cart_order', 'reordered', 'price_range_loc', 'busiest_day',
#        'busiest days', 'max_order', 'loyalty_flag', 'mean_price',
#        'spender_flag', 'median_days_sinse_ord', 'frequent_flag'],
#       dtype='object')

# %%
df.shape
# Out:
# (31156122, 30)

# %%
df.head()
# Out:
#    user_id  Gender       STATE  Age date_joined  n_dependants fam_status  \
# 0    26711  Female    Missouri   48    1/1/2017             3    married
# 1    26711  Female    Missouri   48    1/1/2017             3    married
# 2    26711  Female    Missouri   48    1/1/2017             3    married
# 3    26711  Female    Missouri   48    1/1/2017             3    married
# 4    33890  Female  New Mexico   36    1/1/2017             0     single
#
#    income  product_id              product_name  ...  reordered  \
# 0  165665         196                      Soda  ...          1
# 1  165665        6184               Clementines  ...          1
# 2  165665       38928  0% Greek Strained Yogurt  ...          0
# 3  165665           0                            ...          0
# 4   59285         890    Organic Diced Tomatoes  ...          0
#
#      price_range_loc     busiest_day    busiest days max_order  \
# 0  mid_range_product  Regularly days  Regularly days         9
# ...

# %% [markdown]
# ### 1 creating subset for YLC

# %%
df_LC=df.loc[df['loyalty_flag'].isin(['Loyal customer'])]

# %%
df_LC.head()
# Out:
#      user_id Gender     STATE  Age date_joined  n_dependants fam_status  \
# 224    33835   Male  Nebraska   45    1/1/2017             2    married
# 225    33835   Male  Nebraska   45    1/1/2017             2    married
# 226    33835   Male  Nebraska   45    1/1/2017             2    married
# 227    33835   Male  Nebraska   45    1/1/2017             2    married
# 228    33835   Male  Nebraska   45    1/1/2017             2    married
#
#      income  product_id         product_name  ...  reordered  \
# 224   47988       10258           Pistachios  ...          1
# 225   47988       10258           Pistachios  ...          1
# 226   47988       10258           Pistachios  ...          1
# 227   47988       10258           Pistachios  ...          1
# 228   47988       10441  Dry Roasted Almonds  ...          1
#
#        price_range_loc     busiest_day    busiest days max_order  \
# 224  low_range_product    Busiest days    Busiest days        43
# ...

# %%
df_LC.shape
# Out:
# (10679578, 30)

# %%
df_YLC=df_LC.loc[df_LC ['Age']<=40]

# %%
df_YLC
# Out:
#          user_id  Gender    STATE  Age date_joined  n_dependants  \
# 1163      127020  Female     Ohio   35    1/1/2017             3
# 1164      127020  Female     Ohio   35    1/1/2017             3
# 1165      127020  Female     Ohio   35    1/1/2017             3
# 1166      127020  Female     Ohio   35    1/1/2017             3
# 1167      127020  Female     Ohio   35    1/1/2017             3
# ...          ...     ...      ...  ...         ...           ...
# 6459954    77311  Female  Vermont   21    4/1/2020             1
# 6459955    77311  Female  Vermont   21    4/1/2020             1
# 6459956    77311  Female  Vermont   21    4/1/2020             1
# 6459957    77311  Female  Vermont   21    4/1/2020             1
# 6459958    77311  Female  Vermont   21    4/1/2020             1
#
#                                fam_status  income  product_id  \
# 1163                              married   68933        1096
# ...

# %%
df_YLC.to_pickle(os.path.join(path, 'Prepared data', '0YLC.pkl'))

# %% [markdown]
# ### 2 creating subset for MLC

# %%
df_MLC=df_LC.loc[df_LC ['Age']>40]

# %%
df_MLC.head(3)
# Out:
#      user_id Gender     STATE  Age date_joined  n_dependants fam_status  \
# 224    33835   Male  Nebraska   45    1/1/2017             2    married
# 225    33835   Male  Nebraska   45    1/1/2017             2    married
# 226    33835   Male  Nebraska   45    1/1/2017             2    married
#
#      income  product_id product_name  ...  reordered    price_range_loc  \
# 224   47988       10258   Pistachios  ...          1  low_range_product
# 225   47988       10258   Pistachios  ...          1  low_range_product
# 226   47988       10258   Pistachios  ...          1  low_range_product
#
#       busiest_day  busiest days max_order    loyalty_flag  mean_price  \
# 224  Busiest days  Busiest days        43  Loyal customer    4.168707
# 225  Slowest days  Slowest days        43  Loyal customer    4.168707
# 226  Busiest days  Busiest days        43  Loyal customer    4.168707
#
#      spender_flag  median_days_sinse_ord     frequent_flag
# ...

# %%
df_MLC.to_pickle(os.path.join(path,'prepared data', '0MLC.pkl'))

# %% [markdown]
# ### 3 creating subset for YRC

# %%
df_RC=df.loc[df['loyalty_flag'].isin(['Regular customer'])]

# %%
df_RC.head(3)
# Out:
#    user_id  Gender       STATE  Age date_joined  n_dependants fam_status  \
# 4    33890  Female  New Mexico   36    1/1/2017             0     single
# 5    33890  Female  New Mexico   36    1/1/2017             0     single
# 6    33890  Female  New Mexico   36    1/1/2017             0     single
#
#    income  product_id              product_name  ...  reordered  \
# 4   59285         890    Organic Diced Tomatoes  ...          0
# 5   59285        3298  Mozzarella String Cheese  ...          1
# 6   59285        8953                 Key Limes  ...          0
#
#      price_range_loc     busiest_day    busiest days max_order  \
# 4  low_range_product  Regularly days  Regularly days        13
# 5  low_range_product    Busiest days    Busiest days        13
# 6  mid_range_product    Busiest days    Busiest days        13
#
#        loyalty_flag  mean_price  spender_flag  median_days_sinse_ord  \
# 4  Regular customer    7.057534   Low spender                     26
# ...

# %%
df_YRC=df_RC.loc[df_RC ['Age']<=40]

# %%
df_YRC
# Out:
#          user_id  Gender       STATE  Age date_joined  n_dependants  \
# 4          33890  Female  New Mexico   36    1/1/2017             0
# 5          33890  Female  New Mexico   36    1/1/2017             0
# 6          33890  Female  New Mexico   36    1/1/2017             0
# 7          33890  Female  New Mexico   36    1/1/2017             0
# 8          33890  Female  New Mexico   36    1/1/2017             0
# ...          ...     ...         ...  ...         ...           ...
# 6464332   122741    Male    Michigan   24    4/1/2020             2
# 6464333   122741    Male    Michigan   24    4/1/2020             2
# 6464334   122741    Male    Michigan   24    4/1/2020             2
# 6464335   122741    Male    Michigan   24    4/1/2020             2
# 6464336   122741    Male    Michigan   24    4/1/2020             2
#
#         fam_status  income  product_id  \
# 4           single   59285         890
# 5           single   59285        3298
# ...

# %%
df_YRC.to_pickle(os.path.join(path,'Prepared Data','0YRC.pkl'))

# %% [markdown]
# ### 4 creating subset for MRC

# %%
df_MRC=df_RC.loc[df_RC['Age']>40]

# %%
df_MRC
# Out:
#          user_id Gender      STATE  Age date_joined  n_dependants fam_status  \
# 157        69965   Male      Texas   47    1/1/2017             1    married
# 158        69965   Male      Texas   47    1/1/2017             1    married
# 159        69965   Male      Texas   47    1/1/2017             1    married
# 160        69965   Male      Texas   47    1/1/2017             1    married
# 161        69965   Male      Texas   47    1/1/2017             1    married
# ...          ...    ...        ...  ...         ...           ...        ...
# 6464238    74598   Male  Minnesota   52    4/1/2020             0     single
# 6464239    74598   Male  Minnesota   52    4/1/2020             0     single
# 6464240    74598   Male  Minnesota   52    4/1/2020             0     single
# 6464241    74598   Male  Minnesota   52    4/1/2020             0     single
# 6464242    74598   Male  Minnesota   52    4/1/2020             0     single
#
# ...

# %%
df_MRC.to_pickle(os.path.join(path,'Prepared Data','0MRC.pkl'))

# %% [markdown]
# ### 5 creating subset for YNC

# %%
df_NC=df.loc[df['loyalty_flag']=='New customer']

# %%
df_NC.head(3)
# Out:
#    user_id  Gender     STATE  Age date_joined  n_dependants fam_status  \
# 0    26711  Female  Missouri   48    1/1/2017             3    married
# 1    26711  Female  Missouri   48    1/1/2017             3    married
# 2    26711  Female  Missouri   48    1/1/2017             3    married
#
#    income  product_id              product_name  ...  reordered  \
# 0  165665         196                      Soda  ...          1
# 1  165665        6184               Clementines  ...          1
# 2  165665       38928  0% Greek Strained Yogurt  ...          0
#
#      price_range_loc     busiest_day    busiest days max_order  loyalty_flag  \
# 0  mid_range_product  Regularly days  Regularly days         9  New customer
# 1  low_range_product    Busiest days    Busiest days         9  New customer
# 2  mid_range_product  Regularly days  Regularly days         9  New customer
#
#    mean_price  spender_flag  median_days_sinse_ord     frequent_flag
# ...

# %%
df_YNC=df_NC.loc[df_NC['Age']<=40]

# %%
df_YNC
# Out:
#          user_id  Gender          STATE  Age date_joined  n_dependants  \
# 19         65803    Male          Idaho   35    1/1/2017             2
# 20         65803    Male          Idaho   35    1/1/2017             2
# 21         65803    Male          Idaho   35    1/1/2017             2
# 22         65803    Male          Idaho   35    1/1/2017             2
# 23         65803    Male          Idaho   35    1/1/2017             2
# ...          ...     ...            ...  ...         ...           ...
# 6464309    75529  Female  West Virginia   25    4/1/2020             2
# 6464310    75529  Female  West Virginia   25    4/1/2020             2
# 6464311    75529  Female  West Virginia   25    4/1/2020             2
# 6464312    75529  Female  West Virginia   25    4/1/2020             2
# 6464313    75529  Female  West Virginia   25    4/1/2020             2
#
#         fam_status  income  product_id                         product_name  \
# ...

# %%
df_YNC.to_pickle(os.path.join(path,'Prepared Data', '0YNC.pkl'))

# %% [markdown]
# ### 6 creating subset for MNC

# %%
df_MNC=df_NC.loc[df_NC['Age']>40]

# %%
df_MNC.head(3)
# Out:
#    user_id  Gender     STATE  Age date_joined  n_dependants fam_status  \
# 0    26711  Female  Missouri   48    1/1/2017             3    married
# 1    26711  Female  Missouri   48    1/1/2017             3    married
# 2    26711  Female  Missouri   48    1/1/2017             3    married
#
#    income  product_id              product_name  ...  reordered  \
# 0  165665         196                      Soda  ...          1
# 1  165665        6184               Clementines  ...          1
# 2  165665       38928  0% Greek Strained Yogurt  ...          0
#
#      price_range_loc     busiest_day    busiest days max_order  loyalty_flag  \
# 0  mid_range_product  Regularly days  Regularly days         9  New customer
# 1  low_range_product    Busiest days    Busiest days         9  New customer
# 2  mid_range_product  Regularly days  Regularly days         9  New customer
#
#    mean_price  spender_flag  median_days_sinse_ord     frequent_flag
# ...

# %%
df_MNC.to_pickle(os.path.join(path,'Prepared Data', '0MNC.pkl'))

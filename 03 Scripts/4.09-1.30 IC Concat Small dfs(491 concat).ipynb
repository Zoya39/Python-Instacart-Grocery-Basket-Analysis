# %% [markdown]
# ### 4.9- Part 1. Data Visualization with Python.

# %% [markdown]
# #### 4.9-1 Import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 4.9-1-1 Import files

# %%
path=r'C:\Users\user\07-2023 Instacart Basket Analysis\02 Data'

# %%
df1=pd.read_pickle(os.path.join(path, 'Prepared Data','small1_merged.pkl'))

# %%
df2=pd.read_pickle(os.path.join(path, 'Prepared Data','small2_merged.pkl'))

# %%
df3=pd.read_pickle(os.path.join(path, 'Prepared Data','small3_merged.pkl'))

# %%
df4=pd.read_pickle(os.path.join(path, 'Prepared Data','small4_merged.pkl'))

# %%
df5=pd.read_pickle(os.path.join(path, 'Prepared Data','small5_merged.pkl'))

# %% [markdown]
# ##### 4.9.1-2 cocatenating 5 parts of the merged Instacart data

# %%
frames=[df1,df2,df3,df4,df5]

# %%
df_concat=pd.concat(frames)

# %%
df_concat
# Out:
#          user_id  Gender       STATE  Age date_joined  n_dependants  \
# 0          26711  Female    Missouri   48    1/1/2017             3
# 1          26711  Female    Missouri   48    1/1/2017             3
# 2          26711  Female    Missouri   48    1/1/2017             3
# 3          26711  Female    Missouri   48    1/1/2017             3
# 4          33890  Female  New Mexico   36    1/1/2017             0
# ...          ...     ...         ...  ...         ...           ...
# 6464357    81095  Female  California   27    4/1/2020             1
# 6464358    81095  Female  California   27    4/1/2020             1
# 6464359    81095  Female  California   27    4/1/2020             1
# 6464360    80148  Female    New York   55    4/1/2020             1
# 6464361    80148  Female    New York   55    4/1/2020             1
#
#         fam_status  income         Full_Name  product_id  ... reordered  \
# 0          married  165665  Deborah Esquivel         196  ...         1
# ...

# %%
df_concat.dtypes
# Out:
# user_id                     int64
# Gender                     string
# STATE                      string
# Age                         int64
# date_joined                string
# n_dependants                int64
# fam_status                 string
# income                      int64
# Full_Name                  string
# product_id                  int64
# product_name               string
# aisle_id                    int64
# department_id               int64
# prices                    float64
# order_id                    int64
# eval_set                   string
# order_number                int64
# day_of_week                 int64
# order_hour_of_day           int64
# days_since_prior_order      int64
# add_to_cart_order           int64
# reordered                   int64
# price_range_loc            string
# busiest_day                string
# busiest days               string
# max_order                   int64
# loyalty_flag               string
# ...

# %% [markdown]
# ### 4.9.1-3 Exporting file

# %%
df_concat.to_pickle(os.path.join(path, 'Prepared Data', '491_concat.pkl'))

# %% [markdown]
# ### 4.10 Part4
# #### -creating subst for Yang Basic Consumer
# #### - creating subset for Mature Basic Consumer
# #### -creating subst for Yang Advanced Consumer
# #### - creating subset for Mature Advanced Consumer
# #### -creating subset for Yang Investor
# #### -creating subset for Mature Investor

# %% [markdown]
# ### 4.10.4-1 Importing libraries and df w/o PII

# %%
import pandas as pd
import numpy as np
import os

# %%
path=r'C:\Users\user\07-2023 Instacart Basket Analysis\02 Data'

# %%
df=pd.read_pickle(os.path.join(path,'Prepared Data', 'AgeIncome_flag.pkl'))

# %%
df.columns
# Out:
# Index(['user_id', 'Gender', 'STATE', 'Age', 'date_joined', 'n_dependants',
#        'fam_status', 'income', 'product_id', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'order_id', 'eval_set', 'order_number',
#        'day_of_week', 'order_hour_of_day', 'days_since_prior_order',
#        'add_to_cart_order', 'reordered', 'price_range_loc', 'busiest_day',
#        'busiest days', 'max_order', 'loyalty_flag', 'mean_price',
#        'spender_flag', 'median_days_sinse_ord', 'frequent_flag',
#        'AgeIncome_flag'],
#       dtype='object')

# %%
df.shape
# Out:
# (31156122, 31)

# %%
df.head()
# Out:
#    user_id  Gender     STATE  Age date_joined  n_dependants fam_status  \
# 0    26711  Female  Missouri   48    1/1/2017             3    married
# 1    26711  Female  Missouri   48    1/1/2017             3    married
# 2    26711  Female  Missouri   48    1/1/2017             3    married
# 3    26711  Female  Missouri   48    1/1/2017             3    married
# 4    26711  Female  Missouri   48    1/1/2017             3    married
#
#    income  product_id              product_name  ...    price_range_loc  \
# 0  165665         196                      Soda  ...  mid_range_product
# 1  165665       38928  0% Greek Strained Yogurt  ...  mid_range_product
# 2  165665           0                            ...
# 3  165665       38928  0% Greek Strained Yogurt  ...  mid_range_product
# 4  165665       38928  0% Greek Strained Yogurt  ...  mid_range_product
#
#       busiest_day    busiest days  max_order  loyalty_flag  mean_price  \
# ...

# %% [markdown]
# ### 4.10.4-2 creating subset for YBC

# %%
df_YBC=df.loc[df['AgeIncome_flag'].isin(['young base_consumer'])]

# %%
df_YBC.head()
# Out:
#     user_id  Gender       STATE  Age date_joined  n_dependants fam_status  \
# 8     33890  Female  New Mexico   36    1/1/2017             0     single
# 9     33890  Female  New Mexico   36    1/1/2017             0     single
# 10    33890  Female  New Mexico   36    1/1/2017             0     single
# 11    33890  Female  New Mexico   36    1/1/2017             0     single
# 12    33890  Female  New Mexico   36    1/1/2017             0     single
#
#     income  product_id         product_name  ...    price_range_loc  \
# 8    59285        8953            Key Limes  ...  mid_range_product
# 9    59285       15200  Organic Green Beans  ...  mid_range_product
# 10   59285       27156  Organic Black Beans  ...  mid_range_product
# 11   59285       31912          Avocado Oil  ...  mid_range_product
# 12   59285         196                 Soda  ...  mid_range_product
#
#        busiest_day    busiest days  max_order      loyalty_flag  mean_price  \
# ...

# %%
df_YBC.shape
# Out:
# (11175292, 31)

# %%
df_YBC.to_pickle(os.path.join(path, 'Prepared data', '000YBC.pkl'))

# %% [markdown]
# ### 4.10.4-3 creating subset for MBC

# %%
df_MBC=df.loc[df['AgeIncome_flag'].isin(['mature base_consumer'])]

# %%
df_MBC.head(3)
# Out:
#    user_id  Gender     STATE  Age date_joined  n_dependants fam_status  \
# 0    26711  Female  Missouri   48    1/1/2017             3    married
# 1    26711  Female  Missouri   48    1/1/2017             3    married
# 2    26711  Female  Missouri   48    1/1/2017             3    married
#
#    income  product_id              product_name  ...    price_range_loc  \
# 0  165665         196                      Soda  ...  mid_range_product
# 1  165665       38928  0% Greek Strained Yogurt  ...  mid_range_product
# 2  165665           0                            ...
#
#       busiest_day    busiest days  max_order  loyalty_flag  mean_price  \
# 0  Regularly days  Regularly days          9  New customer    7.988889
# 1  Regularly days  Regularly days          9  New customer    7.988889
# 2  Regularly days  Regularly days          9  New customer    7.988889
#
#    spender_flag  median_days_sinse_ord     frequent_flag        AgeIncome_flag
# ...

# %%
df_MBC.to_pickle(os.path.join(path,'prepared data', '000MBC.pkl'))

# %% [markdown]
# ### 4.10.4-4 creating subset for YAC

# %%
df_YAC=df.loc[df['AgeIncome_flag'].isin(['young advanced_consumer'])]

# %%
df_YAC.head(3)
# Out:
#        user_id Gender       STATE  Age date_joined  n_dependants fam_status  \
# 37454    15683   Male  New Mexico   40    1/5/2017             1    married
# 37455    15683   Male  New Mexico   40    1/5/2017             1    married
# 37456    15683   Male  New Mexico   40    1/5/2017             1    married
#
#        income  product_id   product_name  ...    price_range_loc  \
# 37454  251211        3689     Beef Broth  ...  mid_range_product
# 37455  251211        4605  Yellow Onions  ...  low_range_product
# 37456  251211        8069   Rice Vinegar  ...  mid_range_product
#
#           busiest_day    busiest days  max_order  loyalty_flag  mean_price  \
# 37454    Busiest days    Busiest days         10  New customer  488.641935
# 37455    Busiest days    Busiest days         10  New customer  488.641935
# 37456  Regularly days  Regularly days         10  New customer  488.641935
#
#        spender_flag  median_days_sinse_ord  frequent_flag  \
# ...

# %%
df_YAC.to_pickle(os.path.join(path,'Prepared Data','000YAC.pkl'))

# %% [markdown]
# ### 4.10.4-4 creating subset for MAC

# %%
df_MAC=df.loc[df['AgeIncome_flag'].isin(['mature advanced_consumer'])]

# %%
df_MAC.head(3)
# Out:
#       user_id  Gender   STATE  Age date_joined  n_dependants fam_status  \
# 1522   117740  Female  Oregon   55    1/1/2017             1    married
# 1523   117740  Female  Oregon   55    1/1/2017             1    married
# 1524   117740  Female  Oregon   55    1/1/2017             1    married
#
#       income  product_id                  product_name  ...  \
# 1522  292759        2494  Copper Coated Scrubbing Pads  ...
# 1523  292759        4210                    Whole Milk  ...
# 1524  292759        6052   Eggo Chocolate Chip Waffles  ...
#
#         price_range_loc     busiest_day    busiest days  max_order  \
# 1522  low_range_product    Slowest days    Slowest days         85
# 1523  mid_range_product  Regularly days  Regularly days         85
# 1524  low_range_product    Slowest days    Slowest days         85
#
#         loyalty_flag  mean_price  spender_flag  median_days_sinse_ord  \
# 1522  Loyal customer   36.928431  High spender                      4
# ...

# %%
df_MAC.to_pickle(os.path.join(path,'Prepared Data', '000MAC.pkl'))

# %% [markdown]
# ### 4.10.4-5 creating subset for YI

# %%
df_YI=df.loc[df['AgeIncome_flag'].isin(['young investor'])]

# %%
df_YI.head(3)
# Out:
# Empty DataFrame
# Columns: [user_id, Gender, STATE, Age, date_joined, n_dependants, fam_status, income, product_id, product_name, aisle_id, department_id, prices, order_id, eval_set, order_number, day_of_week, order_hour_of_day, days_since_prior_order, add_to_cart_order, reordered, price_range_loc, busiest_day, busiest days, max_order, loyalty_flag, mean_price, spender_flag, median_days_sinse_ord, frequent_flag, AgeIncome_flag]
# Index: []
#
# [0 rows x 31 columns]

# %%
df_YI.to_pickle(os.path.join(path,'Prepared Data', '000YI.pkl'))

# %% [markdown]
# ### 4.10.4-6 creating subset for MI

# %%
df_MI=df.loc[df['AgeIncome_flag'].isin(['mature investor'])]

# %%
df_MI.head(3)
# Out:
#        user_id Gender       STATE  Age date_joined  n_dependants fam_status  \
# 44145   136298   Male  New Mexico   47    1/6/2017             3    married
# 44146   136298   Male  New Mexico   47    1/6/2017             3    married
# 44147   136298   Male  New Mexico   47    1/6/2017             3    married
#
#        income  product_id                               product_name  ...  \
# 44145  433206       28610   L'Orange Sparkling Natural Mineral Water  ...
# 44146  433206       42240                  Ultra Soft Facial Tissues  ...
# 44147  433206       12817  Original Baked Whole Grain Wheat Crackers  ...
#
#          price_range_loc   busiest_day  busiest days  max_order  \
# 44145  mid_range_product  Busiest days  Busiest days         11
# 44146  mid_range_product  Busiest days  Busiest days         11
# 44147  low_range_product  Slowest days  Slowest days         11
#
#            loyalty_flag  mean_price  spender_flag  median_days_sinse_ord  \
# ...

# %%
df_MI.to_pickle(os.path.join(path,'Prepared Data', '000MI.pkl'))

# %%
x=len(df_YBC)+len(df_YAC)+len(df_YI)+len(df_MBC)+len(df_MAC)+len(df_MI)

# %%
x
# Out:
# 31156122

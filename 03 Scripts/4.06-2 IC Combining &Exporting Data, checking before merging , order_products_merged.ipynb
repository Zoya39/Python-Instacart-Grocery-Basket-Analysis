# %% [markdown]
# ### 4.6.2 IC  Importing libraries
# #### 1 Importing libraries
# #### 2 Importing files
# #### 3 Merging the dfs
# #### 4 Checking by using merge flag
# #### 5 Checking without rewriting df
# #### 6  Exporting the newly created dataframe as orders_products_merged

# %% [markdown]
# ### 1 Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 2 Importing files

# %%
path=r'C:\Users\user\07-2023 Instacart Basket Analysis\02 Data'

# %%
df_orders_products_combined=pd.read_pickle(os.path.join(path,'Prepared Data',
                        'orders_products_combined.pkl'))

# %%
df_orders_products_combined
# Out:
#           order_id  user_id eval_set  order_number  day_of_week  \
# 0          2539329        1    prior             1            2
# 1          2539329        1    prior             1            2
# 2          2539329        1    prior             1            2
# 3          2539329        1    prior             1            2
# 4          2539329        1    prior             1            2
# ...            ...      ...      ...           ...          ...
# 32640693   2977660   206209    prior            13            1
# 32640694   2977660   206209    prior            13            1
# 32640695   2977660   206209    prior            13            1
# 32640696   2977660   206209    prior            13            1
# 32640697    272231   206209    train            14            6
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     0.0       196.0
# 1                         8                     0.0     14084.0
# ...

# %%
df_prods=pd.read_csv(os.path.join(path,'Prepared Data', 'prods_no_duplicates.csv'),index_col=0)

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [markdown]
# ### 3. merging the dfs

# %%
df_prods_merged=df_prods.merge(df_orders_products_combined, on=['product_id'], how='outer', indicator=True)

# %%
df_prods_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                1.0  Chocolate Sandwich Cookies      61.0           19.0
# 1                1.0  Chocolate Sandwich Cookies      61.0           19.0
# 2                1.0  Chocolate Sandwich Cookies      61.0           19.0
# 3                1.0  Chocolate Sandwich Cookies      61.0           19.0
# 4                1.0  Chocolate Sandwich Cookies      61.0           19.0
# ...              ...                         ...       ...            ...
# 32641274     26519.0                         NaN       NaN            NaN
# 32641275     26519.0                         NaN       NaN            NaN
# 32641276     26519.0                         NaN       NaN            NaN
# 32641277     26519.0                         NaN       NaN            NaN
# 32641278     26519.0                         NaN       NaN            NaN
#
#           prices   order_id   user_id eval_set  order_number  day_of_week  \
# ...

# %% [markdown]
# ###  Taking in consideration the size of dfs I prefer to do outer merge

# %% [markdown]
# ### 4. Checking by using merge flag:

# %%
df_prods_merged['_merge'].value_counts()
# Out:
# both          32433030
# right_only      208238
# left_only           11
# Name: _merge, dtype: int64

# %% [markdown]
# ### 5. Checking without rewriting df:

# %%
pd.merge(df_orders_products_combined,df_prods, on=[ 'product_id'], indicator=True)
# Out:
#           order_id  user_id eval_set  order_number  day_of_week  \
# 0          2539329        1    prior             1            2
# 1          2398795        1    prior             2            3
# 2           473747        1    prior             3            3
# 3          2254736        1    prior             4            4
# 4           431534        1    prior             5            4
# ...            ...      ...      ...           ...          ...
# 32433025   1320836   202557    prior            17            2
# 32433026     31526   202557    prior            18            5
# 32433027    758936   203436    prior             1            2
# 32433028   2745165   203436    prior             2            3
# 32433029   3093936   205420    prior             1            4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     0.0       196.0
# 1                         7                    15.0       196.0
# ...

# %%
pd.merge(df_orders_products_combined,df_prods, on=['product_id'], indicator=True) ['_merge'].value_counts()
# Out:
# both          32433030
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# #### Eliminating unusable colunms if needed: df_prods_merge=df_prods_merged.drop(columns=['Unnamed: 0_x','Unnamed: 0_y', '_merge','Unnamed: 0.1'])

# %%
df_prods_merged.shape
# Out:
# (32641279, 15)

# %% [markdown]
# ### 6. Exporting the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size)

# %%
df_prods_merged.to_pickle(os.path.join(path,'Prepared Data','orders_products_merged.pkl'))

# %% [markdown]
# ### 4.7
# #### 1, Importing libraries
# #### 2. Importing df
# #### 3. Creating the “price_label” and “busiest_day” columns
#   #####  -1 Creating subset
#   #####  -2 Creating price_lable function
#   #####  -3 Using price-lable function
#   #####  -4 Counting items according to range
#   #####  -5 Checking the max value
#   #####  -6 Creating the column using If-Statements with the loc() Function
#   ##### -7 Creating column "busiest day"
#     ##### -7-1 geting info which day is: busiest, least busy, regular busy
#     ##### -7-2  creating the separate column 'result'
#     ##### =7-3 adding result column to df
# #### 4. Creating new column indicating two busiest days of the week and the two slowest days
#   ##### 4-1 getting result
#   ##### 4-2  creating the column in df
# #### 5. Exporting file

# %% [markdown]
# ### 1. Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### 2. Importing df

# %%
path=r'C:\Users\user\07-2023 Instacart Basket Analysis\02 Data'

# %%
df_ords_merged=pd.read_pickle(os.path.join(path,'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# ### 3. Creating the “price_label” and “busiest_day” columns

# %% [markdown]
# #### 3-1 Creating subset

# %%
df_ords_merged.shape
# Out:
# (32641279, 15)

# %%
df_ords_part=df_ords_merged[:1000000]

# %% [markdown]
# #### 3-2 Creating price_lable function

# %%
def price_lable(row):
    
    if row['prices']<=5:
        return'low-range product'
    elif (row['prices']>5) and (row['prices']<15):
        return 'mid-range product'
    elif row['prices']>=15:
        return 'hight range'
    else: return 'not enouth data'

# %% [markdown]
# #### 3-3 Using price-lable function

# %%
df_ords_part['price_range']=df_ords_part.apply(price_lable, axis=1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8872\1097614506.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_part['price_range']=df_ords_part.apply(price_lable, axis=1)

# %% [markdown]
# #### the red sentence is not abot mistake but about warning

# %% [markdown]
# #### 3-4 Counting items according to range

# %%
df_ords_part['price_range'].value_counts(dropna=False)
# Out:
# mid-range product    650777
# low-range product    331238
# hight range           17985
# Name: price_range, dtype: int64

# %% [markdown]
# #### 3-5 Checking the max value

# %%
df_ords_part['prices'].max()
# Out:
# 24.5

# %% [markdown]
# #### 3-6 Creating the column using If-Statements with the loc() Function

# %%
df_ords_merged.loc[df_ords_merged['prices']>15, 'price_range_loc']='hight_range_product'

# %%
df_ords_merged.loc[(df_ords_merged['prices']<=15)&(df_ords_merged['prices']>5), 'price_range_loc']='mid_range_product'

# %%
df_ords_merged.loc[df_ords_merged['prices']<=5,'price_range_loc']='low_range_product'

# %%
df_ords_merged.head(2)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0         1.0  Chocolate Sandwich Cookies      61.0           19.0     5.8
# 1         1.0  Chocolate Sandwich Cookies      61.0           19.0     5.8
#
#     order_id  user_id eval_set  order_number  day_of_week  order_hour_of_day  \
# 0  3139998.0    138.0    prior          28.0          6.0               11.0
# 1  1977647.0    138.0    prior          30.0          6.0               17.0
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# 0                     3.0                5.0        0.0   both
# 1                    20.0                1.0        1.0   both
#
#      price_range_loc
# 0  mid_range_product
# 1  mid_range_product

# %%
df_ords_merged['price_range_loc'].value_counts(dropna=False)
# Out:
# mid_range_product      21889017
# low_range_product      10126342
# hight_range_product      417682
# NaN                      208238
# Name: price_range_loc, dtype: int64

# %% [markdown]
# #### -7. Creating column "busiest day"

# %% [markdown]
# ##### -7-1 geting info which day is: busiest, least busy, regular busy

# %%
df_ords_merged['day_of_week'].value_counts(dropna=False)
# Out:
# 0.0    6252941
# 1.0    5696724
# 6.0    4530304
# 2.0    4243173
# 5.0    4236989
# 3.0    3868747
# 4.0    3812390
# NaN         11
# Name: day_of_week, dtype: int64

# %% [markdown]
# ##### -7-2 creating the separate column 'result'

# %%
result = []

for value in df_ords_merged ["day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# ##### -7-3 adding result column to df

# %%
df_ords_merged['busiest_day']=result

# %%
df_ords_merged['busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    22575948
# Busiest day        6252941
# Least busy         3812390
# Name: busiest_day, dtype: int64

# %%
df_ords_merged.head(2)
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0         1.0  Chocolate Sandwich Cookies      61.0           19.0     5.8
# 1         1.0  Chocolate Sandwich Cookies      61.0           19.0     5.8
#
#     order_id  user_id eval_set  order_number  day_of_week  order_hour_of_day  \
# 0  3139998.0    138.0    prior          28.0          6.0               11.0
# 1  1977647.0    138.0    prior          30.0          6.0               17.0
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# 0                     3.0                5.0        0.0   both
# 1                    20.0                1.0        1.0   both
#
#      price_range_loc     busiest_day
# 0  mid_range_product  Regularly busy
# 1  mid_range_product  Regularly busy

# %% [markdown]
# ### 4.  Creating new column indicating two busiest days of the week and the two slowest days

# %% [markdown]
# ####  4-1 getting result (using the data  I assumed the two busiest days are -0 and 1, the two slowest days are -3 and 4. )

# %%
result=[]

for value in df_ords_merged["day_of_week"]:
        if value==0: 
            result.append("Busiest days")
        elif value==1: 
            result.append("Busiest days")
        elif value==3: 
            result.append("Slowest days")
        elif value==4: 
            result.append("Slowest days")
        else: result.append("Regularly days")

# %% [markdown]
# #### 4-2 creating the column in df

# %%
df_ords_merged['busiest days']=result

# %%
df_ords_merged['busiest days'].value_counts(dropna=False)
# Out:
# Regularly days    13010477
# Busiest days      11949665
# Slowest days       7681137
# Name: busiest days, dtype: int64

# %%
df_ords_merged.shape
# Out:
# (32641279, 18)

# %% [markdown]
# ### 5. exporting file

# %%
df_ords_merged.to_pickle(os.path.join (path, 'Prepared Data', 'ords_merged_bdays.pkl'))
